# %% [markdown]
# # Sunil Choudhary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## read csv file

df= pd.read_csv('loan.csv')
# Out:
# C:\Users\sunil\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df.head())
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
print(df.head(1))
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
#
# [1 rows x 111 columns]

# %%
list1=list(df.columns)
print(list1)
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'year']

# %%
## new data frame df2
df2 = df.drop(['id', 'member_id', 'sub_grade', 'emp_title', 'emp_length',  'verification_status', 'issue_d',  'pymnt_plan', 'url', 'desc', 'title', 'zip_code', 'addr_state', 'dti', 'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit'],axis=1)

# %%
print(df2.columns)
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'home_ownership', 'annual_inc', 'loan_status',
#        'purpose', 'delinq_2yrs', 'mths_since_last_delinq', 'total_rec_int'],
#       dtype='object')

# %% [markdown]
# # finding the frequency of loan purpose

# %%
fig, ax = plt.subplots()
fig.set_size_inches(23, 10)
sns.countplot(x='purpose', data=df2)
plt.title("Frequency plot of Loan Purpose")
plt.xlabel('Loan Purpose')
plt.yscale('log')
plt.show()

# %% [markdown]
# From the above plot we can see that highest number of borrowers have taken debt consolidation loan, followed by credit_card loan, followed by other loan, home_improvement loan, etc.

# %% [markdown]
# # univariate analysis on int_rate column

# %%
#  handling data quality issues in int_rate column
df2['int_rate'] = df2.int_rate.str.strip('%')
df2['int_rate'] = df2.int_rate.astype(float)

fig, ax = plt.subplots()
fig.set_size_inches(14, 7)
sns.boxplot(x='int_rate', data=df2)
plt.title('Distribution of interest rates')
plt.xlabel('Interest rates')
plt.show()

# %% [markdown]
# From the above plot we can see that the interest rates of most of the loans are between 9% to 14.5% and median is at around 11.5%
# Outlier detection:
# From the above plot we can observe that there are outliers after the right whisker. Interest rates above 22.5% are outliers.

# %% [markdown]
# # univariate analysis on Loan Status column

# %%
# Checking data quality issues in Loan status column

df2.loan_status.unique()
# Out:
# array(['Fully Paid', 'Charged Off', nan], dtype=object)

# %%
from collections import Counter

paid_percent = round(sum(df.loan_status == 'Fully Paid')/len(df) * 100, 2)
charged_off_percent = round(sum(df.loan_status == 'Charged Off')/len(df) * 100, 2)
current_percent = round(sum(df.loan_status == 'Current')/len(df) * 100, 2)

cts = Counter(df.loan_status.unique())
fig, ax = plt.subplots()
fig.set_size_inches(10, 9)
plt.pie([paid_percent, charged_off_percent, current_percent], labels=cts.keys(), autopct='%1.0f%%')
plt.title('Percentage of loans fully paid, charged off and current')
# Out:
# Text(0.5, 1.0, 'Percentage of loans fully paid, charged off and current')

# %% [markdown]
# As we can see from the plot above that majority (83%) of the borrowers have paid the full amount back. 14% of the borrowers are charged off and 3% of the borrowers are currently repaying loans.

# %%
###### As rows with loan_status = current, are not useful for analysis, we can remove those rows
df2.loan_status = df2.loc[df2.loan_status != 'Current', 'loan_status']

# %%
df2.grade.value_counts()
# Out:
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %% [markdown]
# # Univariate analysis on grade column

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
sns.countplot(x='grade', data=df2)
plt.title("Frequency plot of loan grades")
plt.xlabel('Loan Grades')
plt.show()

# %% [markdown]
# From the above plot, we can see that majority of the loans were given Grade-B, followed by Grade-A, Grade-C, etc.

# %%
df2.annual_inc.min()
# Out:
# 4000.0

# %%
df2.annual_inc.max()
# Out:
# 6000000.0

# %%
df2.annual_inc.describe()
# Out:
# count    3.971700e+04
# mean     6.896893e+04
# std      6.379377e+04
# min      4.000000e+03
# 25%      4.040400e+04
# 50%      5.900000e+04
# 75%      8.230000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# # Performing univariate analysis of annual income column

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
sns.distplot(df2['annual_inc'])
plt.yscale('log')
plt.show()

# %% [markdown]
# From the above plot we can see that majority of loan applicant's annual income is less than 10 lakhs.
# Outlier detection:
# From the above plot we can observe that there are some outliers. But because of very few outliers, mean has not been skewed.

# %% [markdown]
# # plotting a correlation matrix for entire data to identify the patterns

# %%
loan_correlation_matrix = df2.corr()
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
sns.heatmap(loan_correlation_matrix, ax = ax, cmap ="YlGnBu", linewidths = 0.1) 
plt.show()

# %% [markdown]
# loan_amnt', 'funded_amnt_inv', 'funded_amnt' are highly correlated.
# issued some loan that differs from the requested amount

# %% [markdown]
# # Bivariate analysis on loan status and interest rate

# %%
fig, ax = plt.subplots()
fig.set_size_inches(14, 7)
sns.boxplot(y='int_rate', x='loan_status', data=df2)
plt.title('Box plot for loan status versus interest rate')
plt.ylabel('Interest rates')
plt.show()

# %% [markdown]
# We can see from the above plot that higher the interest rate, higher the chances of loan getting charged off

# %% [markdown]
# # Bivariate analysis on two categorical variables loan status and grade

# %%
loan_crosstab = pd.crosstab(df2['grade'], df2['loan_status'])
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

# calculating percentages grade-wise
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

# dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)
print(loan_crosstab)

loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Grade versus Loan Status')
# Out:
# loan_status  charged_off_percentage  fully_paid_percentage
# grade
# A                              5.99                  94.01
# B                             12.21                  87.79
# C                             17.19                  82.81
# D                             21.99                  78.01
# E                             26.85                  73.15
# F                             32.68                  67.32
# G                             33.78                  66.22

# %% [markdown]
# From the above plot we can see that as we move from higer grade to lower grade i.e from Grade-A to Grade-G, the percentage of charged_off is increasing. There is a correlation between loan defaulting and grade.

# %% [markdown]
# # Bivariate analysis on loan status and Term

# %%
loan_crosstab = pd.crosstab(df['term'], df['loan_status'])
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

# calculating percentages
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

# dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)
print(loan_crosstab)

loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Term versus Loan Status')
# Out:
# loan_status  Current  charged_off_percentage  fully_paid_percentage
# term
#  36 months         0                   11.09                  88.91
#  60 months      1140                   25.31                  74.69

# %% [markdown]
# From the above plot we can see that 60 months term loans are more likely to get default.

# %% [markdown]
# # Bivariate analysis on loan status and pub_rec_bankruptcies

# %%
loan_crosstab = pd.crosstab(df['pub_rec_bankruptcies'], df['loan_status'])
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

# calculating percentages 
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

# dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)
print(loan_crosstab)

loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Total Bank Ruptcies versus Loan Status')
# Out:
# loan_status           Current  charged_off_percentage  fully_paid_percentage
# pub_rec_bankruptcies
# 0.0                      1101                   14.19                  85.81
# 1.0                        37                   22.36                  77.64
# 2.0                         2                   40.00                  60.00

# %% [markdown]
# Customer with public bankruptcy history of 1 or more is more likely to get default

# %% [markdown]
# # Bivariate analysis two categorical variables loan status and dti

# %%
fig, ax = plt.subplots()
fig.set_size_inches(14, 7)
sns.boxplot(y='dti', x='loan_status', data=df)
plt.title('Box plot for loan status versus dti')
plt.ylabel('Debt to Income Ratio')
plt.show()

# %% [markdown]
# Significant correlation is not there between debt to income ratio and loan defaulting

# %%
##############   Derived Metrics  ##################
## Derived year from issue_d column and used it for bivariate analysis

df.issue_d.value_counts()
df['year'] = df.issue_d.str.split("-").apply(lambda x: x[1])

# %%
df.year
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 39712    07
# 39713    07
# 39714    07
# 39715    07
# 39716    07
# Name: year, Length: 39717, dtype: object

# %% [markdown]
# # Bivariate analysis on loan status and year

# %%
loan_crosstab = pd.crosstab(df['year'], df['loan_status'])
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

# calculating percentages 
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

# dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)
print(loan_crosstab)

loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Year versus Loan Status')
# Out:
# loan_status  Current  charged_off_percentage  fully_paid_percentage
# year
# 07                 0                   17.93                  82.07
# 08                 0                   15.81                  84.19
# 09                 0                   12.60                  87.40
# 10                 0                   12.88                  87.12
# 11              1140                   15.87                  84.13

# %% [markdown]
# In year 2007 there were more defaults probably because of recession as rest of the following year were good in terms of loan repayment. Hence Lending loans during recession could be a factor

# %% [markdown]
# # Bivariate analysis on loan status and delinq_2yrs

# %%
loan_crosstab = pd.crosstab(df['delinq_2yrs'], df['loan_status'])
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

# calculating percentages
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

# dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)
print(loan_crosstab)

loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Delinq for 2 year versus Loan Status')
# Out:
# loan_status  Current  charged_off_percentage  fully_paid_percentage
# delinq_2yrs
# 0               1019                   14.35                  85.65
# 1                 96                   15.81                  84.19
# 2                 14                   19.32                  80.68
# 3                  8                   16.51                  83.49
# 4                  2                   21.67                  78.33
# 5                  1                   14.29                  85.71
# 6                  0                   10.00                  90.00
# 7                  0                   25.00                  75.00
# 8                  0                   50.00                  50.00
# 9                  0                    0.00                 100.00
# 11                 0                    0.00                 100.00

# %% [markdown]
# Delinq_2 years - customers who were delinquent for 7 and 8 times in last 2 years were tend to default 25% and 50% of the times. But this factor wouldn't help us much as waiting for such long time without any action would not be a wise thing to do

# %% [markdown]
# # Bivariate analysis on loan status and addr_state

# %%
loan_crosstab = pd.crosstab(df['addr_state'], df['loan_status'])
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

### calculating percentages
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

######## dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)
print(loan_crosstab)
loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Address State versus Loan Status')
# Out:
# loan_status  Current  charged_off_percentage  fully_paid_percentage
# addr_state
# AK                 2                   19.23                  80.77
# AL                17                   12.41                  87.59
# AR                10                   11.49                  88.51
# AZ                30                   14.49                  85.51
# CA               150                   16.19                  83.81
# CO                26                   12.79                  87.21
# CT                25                   12.95                  87.05
# DC                 3                    7.11                  92.89
# DE                 1                   10.62                  89.38
# FL                85                   18.12                  81.88
# GA                39                   15.82                  84.18
# HI                 8                   16.87                  83.13
# IA                 0                    0.00                 100.00
# ID                 0                   16.67                  83.33
# IL                47                   13.33                  86.67
# IN                 0                    0.00                 100.00
# KS                16                   12.16                  87.84
# KY                14                   14.47                  85.53
# LA                 9                   12.41                  87.59
# MA                43                   12.26                  87.74
# MD                26                   15.84                  84.16
# ME                 0                    0.00                 100.00
# MI                16                   14.63                  85.37
# MN                10                   13.39                  86.61
# MO                16                   17.01                  82.99
# MS                 0                   10.53                  89.47
# MT                 2                   13.25                  86.75
# NC                38                   15.20                  84.80
# NE                 0                   60.00                  40.00
# NH                 5                   15.06                  84.94
# NJ                60                   15.53                  84.47
# NM                 6                   16.39                  83.61
# NV                18                   22.55                  77.45
# NY               114                   13.39                  86.61
# OH                45                   13.16                  86.84
# OK                12                   13.94                  86.06
# OR                16                   16.32                  83.68
# PA                49                   12.26                  87.74
# RI                 4                   12.89                  87.11
# SC                13                   14.38                  85.62
# SD                 2                   19.35                  80.65
# TN                 0                   11.76                  88.24
# TX                68                   11.88                  88.12
# UT                 6                   15.87                  84.13
# VA                38                   12.93                  87.07
# VT                 1                   11.32                  88.68
# WA                22                   15.53                  84.47
# WI                20                   14.32                  85.68
# WV                 5                   12.21                  87.79
# WY                 3                    5.00                  95.00

# %% [markdown]
# TN, AK and NV has seen most number of default cases compared to the other states. Lending club should be extra cautious while lending in these states

# %% [markdown]
# # Bivariate analysis two categorical variables loan status and employee length

# %%
loan_crosstab = pd.crosstab(df['emp_length'], df['loan_status'], normalize=True).round(4)*100 
loan_crosstab['sum_of_charged_off_and_fully_paid'] = loan_crosstab['Charged Off'] + loan_crosstab['Fully Paid']

# calculating percentages
loan_crosstab['charged_off_percentage'] = round((loan_crosstab['Charged Off']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)
loan_crosstab['fully_paid_percentage'] = round((loan_crosstab['Fully Paid']/loan_crosstab.sum_of_charged_off_and_fully_paid)*100, 2)

# dropping unnecessary columns in contingency table
loan_crosstab.drop(columns=['Charged Off', 'Fully Paid', 'sum_of_charged_off_and_fully_paid'], inplace=True)

print(loan_crosstab)

loan_crosstab.sort_values(by='charged_off_percentage').plot.bar(stacked=False, figsize=(14,7),  title='Employee Experience versus Loan Status')
# Out:
# loan_status  Current  charged_off_percentage  fully_paid_percentage
# emp_length
# 1 year          0.18                   14.39                  85.61
# 10+ years       1.01                   15.66                  84.34
# 2 years         0.25                   13.23                  86.77
# 3 years         0.21                   13.86                  86.14
# 4 years         0.24                   13.87                  86.13
# 5 years         0.23                   14.39                  85.61
# 6 years         0.16                   14.08                  85.92
# 7 years         0.16                   15.35                  84.65
# 8 years         0.11                   14.25                  85.75
# 9 years         0.08                   12.93                  87.07
# < 1 year        0.19                   14.15                  85.85

# %% [markdown]
# Could not find any correlation between employee length and loan defaulting
